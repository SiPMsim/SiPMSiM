# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
signal=np.load('../result/signal.npy')
plt.plot(signal['time'], signal['value'])
plt.xlabel('Time (ns)')
plt.ylabel('Amplitude (V)')
# Out:
# Text(0, 0.5, 'Amplitude (V)')
